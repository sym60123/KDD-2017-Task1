# %%
import pandas as pd
pd.read_csv('travel_time_feature.csv').fillna(0)
# Out:
#     day_of_year  time_A_2_6_0  time_A_2_6_20  time_A_2_6_40  time_A_2_7_0  \
# 0           201         46.36          48.59          66.64         64.68
# 1           202         44.10          59.87          88.81         77.85
# 2           203         63.18          87.03          65.34         78.01
# 3           204         65.36          57.04          63.97        132.22
# 4           205        329.73          80.13          82.56         87.63
# 5           206         36.17          63.18          60.76        106.39
# 6           207         50.70          40.39          63.42         85.79
# 7           208         29.64          83.02          55.28         64.60
# 8           209         23.06          77.40          74.66         91.73
# 9           210         44.26          55.89          64.15         56.91
# 10          211         41.71          59.76          60.58         68.89
# 11          212         50.60          44.54          54.22         80.87
# ...
