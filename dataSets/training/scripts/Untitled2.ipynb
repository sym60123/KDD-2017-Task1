# %%
import pandas as pd
import sklearn

# %%
posts = pd.read_pickle('../Before.pickle')

# %%
table= posts[(posts.hour < 8)
             &(posts.hour  >= 6)]

# %%
from IPython.display import display_html

for key,value in table.groupby(['intersection_id','tollgate_id','day_of_year']):
    display_html(value.to_html(), raw = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>intersection_id</th>
#       <th>tollgate_id</th>
#       <th>day_in_month</th>
#       <th>day_of_week</th>
#       <th>day_of_year</th>
#       <th>hour</th>
#       <th>minute</th>
#       <th>month</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13410</th>
#       <td>0</td>
#       <td>2</td>
#       <td>31</td>
#       <td>1</td>
#       <td>201</td>
#       <td>6</td>
#       <td>0</td>
#       <td>7</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>13411</th>
#       <td>0</td>
#       <td>2</td>
#       <td>31</td>
#       <td>1</td>
#       <td>201</td>
#       <td>6</td>
#       <td>20</td>
#       <td>7</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>13412</th>
#       <td>0</td>
#       <td>2</td>
#       <td>31</td>
#       <td>1</td>
#       <td>201</td>
#       <td>6</td>
# ...

# %%
from IPython.display import display_html
display_html(value.to_html(), raw = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>intersection_id</th>
#       <th>tollgate_id</th>
#       <th>day_in_month</th>
#       <th>day_of_week</th>
#       <th>day_of_year</th>
#       <th>hour</th>
#       <th>minute</th>
#       <th>month</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>25079</th>
#       <td>2</td>
#       <td>3</td>
#       <td>31</td>
#       <td>6</td>
#       <td>290</td>
#       <td>7</td>
#       <td>40</td>
#       <td>10</td>
#       <td>2016</td>
#     </tr>
#   </tbody>
# </table>

# %%
t = pd.read_csv('../training_20min_avg_travel_time.csv')

# %%
t
# Out:
#       intersection_id  tollgate_id                                time_window  \
# 0                   B            3  [2016-07-19 00:00:00,2016-07-19 00:20:00)
# 1                   B            3  [2016-07-19 00:20:00,2016-07-19 00:40:00)
# 2                   B            3  [2016-07-19 01:40:00,2016-07-19 02:00:00)
# 3                   B            3  [2016-07-19 02:00:00,2016-07-19 02:20:00)
# 4                   B            3  [2016-07-19 02:40:00,2016-07-19 03:00:00)
# 5                   B            3  [2016-07-19 03:40:00,2016-07-19 04:00:00)
# 6                   B            3  [2016-07-19 04:00:00,2016-07-19 04:20:00)
# 7                   B            3  [2016-07-19 04:20:00,2016-07-19 04:40:00)
# 8                   B            3  [2016-07-19 04:40:00,2016-07-19 05:00:00)
# 9                   B            3  [2016-07-19 05:00:00,2016-07-19 05:20:00)
# 10                  B            3  [2016-07-19 06:00:00,2016-07-19 06:20:00)
# ...
